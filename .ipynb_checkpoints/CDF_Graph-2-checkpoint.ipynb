# %%
import pandas as pd
import json
from ripe.atlas.cousteau import (
    AtlasResultsRequest
)
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
#CDF of RTT for ping

kwargs = {
    "msm_id": 38331308
}

is_success, results = AtlasResultsRequest(**kwargs).create()

if is_success:
    #print the json string
    #print(results)

    #df1 = pd.json_normalize(results)
    #display(df1)
    
    num=0
    
    #for x, row in df1.iterrows():
        #df1['result'][x] = pd.json_normalize(df1['result'][x])

    
    df2 = pd.DataFrame(results)
    display(df2)
    just_rtt = []

    #print(df2[results])
       
    for x, row in df2.iterrows():
        #df2['result'][x] = pd.json_normalize(df2['result'][x])
        #df2['rtt'] = df2['result'][x].astype(float)
        #for rtt in df2['result'][x]:
            #for i in rtt:
                #num=num+1
                #just_rtt.append(df2['result'][x][rtt])
            
        just_rtt.append(df2['min'])
        num = num + 1
        just_rtt.append(df2['max'])
        num = num + 1
        just_rtt.append(df2['avg'])
        num = num + 1
        #df2['rtt'].plot(x='', y='RTT', title = "RTT Results", grid = True)
    
    print(num)
    #print(just_rtt)
    
N = num
data = np.array(just_rtt)


count, bins_count = np.histogram(data, bins=40)
pdf = count / sum(count)

cdf = np.cumsum(pdf)

#plt.plot(bins_count[1:], pdf, color="red", label="PDF")
plt.plot(bins_count[1:], cdf, label="CDF")
plt.axis([0,140,0,1.0])
plt.legend()
# Out:
#        fw   mver  lts      dst_name  af      dst_addr        src_addr proto  \
# 0    5020  2.3.2   32  149.149.2.70   4  149.149.2.70  50.231.101.252  ICMP
# 1    5040  2.4.1   17  149.149.2.70   4  149.149.2.70   192.168.10.21  ICMP
# 2    5040  2.4.1   16  149.149.2.70   4  149.149.2.70   192.168.0.144  ICMP
# 3    5040  2.4.1    9  149.149.2.70   4  149.149.2.70    192.168.50.5  ICMP
# 4    5040  2.4.1    5  149.149.2.70   4  149.149.2.70    192.168.2.51  ICMP
# ..    ...    ...  ...           ...  ..           ...             ...   ...
# 115  5020  2.3.2   30  149.149.2.70   4  149.149.2.70  50.231.101.252  ICMP
# 116  5040  2.4.1   20  149.149.2.70   4  149.149.2.70   192.168.10.21  ICMP
# 117  5040  2.4.1   24  149.149.2.70   4  149.149.2.70   192.168.0.144  ICMP
# 118  5040  2.4.1   14  149.149.2.70   4  149.149.2.70    192.168.50.5  ICMP
# 119  5040  2.4.1    2  149.149.2.70   4  149.149.2.70    192.168.2.51  ICMP
#
#      ttl  size  ...        avg    msm_id   prb_id   timestamp  msm_name  \
# 0     52    48  ...  29.880469  38331308  1002666  1644183581      Ping
# 1     51    48  ...  33.003966  38331308    34661  1644183583      Ping
# 2     49    48  ...  39.463459  38331308    52391  1644183585      Ping
# 3     49    48  ...  46.254639  38331308    54348  1644183580      Ping
# 4     55    48  ...  28.754611  38331308    54566  1644183576      Ping
# ..   ...   ...  ...        ...       ...      ...         ...       ...
# 115   52    48  ...  29.903103  38331308  1002666  1644266374      Ping
# 116   51    48  ...  63.207571  38331308    34661  1644266384      Ping
# 117   49    48  ...  42.286695  38331308    52391  1644266387      Ping
# 118   49    48  ...  45.101111  38331308    54348  1644266379      Ping
# 119   55    48  ...  28.232375  38331308    54566  1644266375      Ping
#
#                 from  type  group_id  step  stored_timestamp
# 0     50.231.101.252  ping  38331308  3600        1644183603
# 1    108.189.226.221  ping  38331308  3600        1644183641
# 2      104.60.195.61  ping  38331308  3600        1644183646
# 3      24.44.255.251  ping  38331308  3600        1644183709
# 4     138.88.222.209  ping  38331308  3600        1644183656
# ..               ...   ...       ...   ...               ...
# 115   50.231.101.252  ping  38331308  3600        1644266404
# 116  108.189.226.221  ping  38331308  3600        1644266436
# 117    104.60.195.61  ping  38331308  3600        1644266439
# 118    24.44.255.251  ping  38331308  3600        1644266420
# 119   138.88.222.209  ping  38331308  3600        1644266464
#
# [120 rows x 26 columns]
# 360

# %%
#CDF of packet loss for ping

kwargs = {
    "msm_id": 38331308
}

#Request Ripe-atlas results
is_success, results = AtlasResultsRequest(**kwargs).create()

if is_success:
    #print the json string
    #print(results)

    #df1 = pd.json_normalize(results)
    #display(df1)
    
    num=0
    
    #for x, row in df1.iterrows():
        #df1['result'][x] = pd.json_normalize(df1['result'][x])

    #place results in pandas dataframe
    df2 = pd.DataFrame(results)
    display(df2)
    sent = []
    received = []

    #print(df2[results])
    
    #For each row in the dataframe, append packets sent to the "sent" list and packets received to the "received" list
    for x, row in df2.iterrows():
        #df2['result'][x] = pd.json_normalize(df2['result'][x])
        #df2['rtt'] = df2['result'][x].astype(float)
        #for rtt in df2['result'][x]:
            #for i in rtt:
                #num=num+1
                #just_rtt.append(df2['result'][x][rtt])
            
        sent.append(df2['sent'])
        num = num + 1
        received.append(df2['rcvd'])
        
        #df2['rtt'].plot(x='', y='RTT', title = "RTT Results", grid = True)
        
    total_loss = []
    zip_object = zip(sent, received)
    for sent, received in zip_object:
        total_loss.append(sent-received)
    
    print(num)
    #print(just_rtt)
    
N = num
data = np.array(total_loss)


count, bins_count = np.histogram(data, bins=40)
pdf = count / sum(count)

cdf = np.cumsum(pdf)

#plt.plot(bins_count[1:], pdf, color="red", label="PDF")
plt.plot(bins_count[1:], cdf, label="CDF")
plt.axis([0,50,0,1.0])
plt.legend()
# Out:
#        fw   mver  lts      dst_name  af      dst_addr        src_addr proto  \
# 0    5020  2.3.2   32  149.149.2.70   4  149.149.2.70  50.231.101.252  ICMP
# 1    5040  2.4.1   17  149.149.2.70   4  149.149.2.70   192.168.10.21  ICMP
# 2    5040  2.4.1   16  149.149.2.70   4  149.149.2.70   192.168.0.144  ICMP
# 3    5040  2.4.1    9  149.149.2.70   4  149.149.2.70    192.168.50.5  ICMP
# 4    5040  2.4.1    5  149.149.2.70   4  149.149.2.70    192.168.2.51  ICMP
# ..    ...    ...  ...           ...  ..           ...             ...   ...
# 115  5020  2.3.2   30  149.149.2.70   4  149.149.2.70  50.231.101.252  ICMP
# 116  5040  2.4.1   20  149.149.2.70   4  149.149.2.70   192.168.10.21  ICMP
# 117  5040  2.4.1   24  149.149.2.70   4  149.149.2.70   192.168.0.144  ICMP
# 118  5040  2.4.1   14  149.149.2.70   4  149.149.2.70    192.168.50.5  ICMP
# 119  5040  2.4.1    2  149.149.2.70   4  149.149.2.70    192.168.2.51  ICMP
#
#      ttl  size  ...        avg    msm_id   prb_id   timestamp  msm_name  \
# 0     52    48  ...  29.880469  38331308  1002666  1644183581      Ping
# 1     51    48  ...  33.003966  38331308    34661  1644183583      Ping
# 2     49    48  ...  39.463459  38331308    52391  1644183585      Ping
# 3     49    48  ...  46.254639  38331308    54348  1644183580      Ping
# 4     55    48  ...  28.754611  38331308    54566  1644183576      Ping
# ..   ...   ...  ...        ...       ...      ...         ...       ...
# 115   52    48  ...  29.903103  38331308  1002666  1644266374      Ping
# 116   51    48  ...  63.207571  38331308    34661  1644266384      Ping
# 117   49    48  ...  42.286695  38331308    52391  1644266387      Ping
# 118   49    48  ...  45.101111  38331308    54348  1644266379      Ping
# 119   55    48  ...  28.232375  38331308    54566  1644266375      Ping
#
#                 from  type  group_id  step  stored_timestamp
# 0     50.231.101.252  ping  38331308  3600        1644183603
# 1    108.189.226.221  ping  38331308  3600        1644183641
# 2      104.60.195.61  ping  38331308  3600        1644183646
# 3      24.44.255.251  ping  38331308  3600        1644183709
# 4     138.88.222.209  ping  38331308  3600        1644183656
# ..               ...   ...       ...   ...               ...
# 115   50.231.101.252  ping  38331308  3600        1644266404
# 116  108.189.226.221  ping  38331308  3600        1644266436
# 117    104.60.195.61  ping  38331308  3600        1644266439
# 118    24.44.255.251  ping  38331308  3600        1644266420
# 119   138.88.222.209  ping  38331308  3600        1644266464
#
# [120 rows x 26 columns]
# 120

# %%
kwargs = {
    "msm_id": 38384555
}

is_success, results = AtlasResultsRequest(**kwargs).create()

if is_success:
    #print the json string
    #print(results)
    
    df1 = pd.json_normalize(results)
#    df1 = pd.json_normalize(results,max_level=0)

    display(df1['result'][1])
    
    just_rtt = []
    
#    for x, row in df2.iterrows():
#        df2['result'][x] = pd.json_normalize(df2['result'][x])
#        display(df2['result'][x])
#        for rtt in df2['result'][x]:
#            just_rtt.append(df2['result'][x][rtt])
#            num = num + 1
        
#    print(num)
            
#data = np.array(just_rtt)


#count, bins_count = np.histogram(data, bins=25)
#pdf = count / sum(count)

#cdf = np.cumsum(pdf)


#plt.plot(bins_count[1:], pdf, color="red", label="PDF")
#plt.plot(bins_count[1:], cdf, label="CDF")
#plt.legend()
# Out:
# [{'hop': 1,
#   'result': [{'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 1.087},
#    {'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 0.932},
#    {'from': '192.168.0.1', 'ttl': 64, 'size': 76, 'rtt': 3.759}]},
#  {'hop': 2,
#   'result': [{'from': '192.168.1.254', 'ttl': 63, 'size': 76, 'rtt': 2.011},
#    {'from': '192.168.1.254', 'ttl': 63, 'size': 76, 'rtt': 1.475},
#    {'from': '192.168.1.254', 'ttl': 63, 'size': 76, 'rtt': 2.828}]},
#  {'hop': 3,
#   'result': [{'from': '107.204.182.1', 'ttl': 62, 'size': 76, 'rtt': 4.855},
#    {'from': '107.204.182.1', 'ttl': 62, 'size': 76, 'rtt': 3.488},
#    {'from': '107.204.182.1', 'ttl': 62, 'size': 76, 'rtt': 5.247}]},
#  {'hop': 4,
#   'result': [{'from': '76.229.12.76', 'ttl': 61, 'size': 76, 'rtt': 3.366},
#    {'from': '76.229.12.76', 'ttl': 61, 'size': 76, 'rtt': 2.912},
#    {'from': '76.229.12.76', 'ttl': 61, 'size': 76, 'rtt': 4.252}]},
#  {'hop': 5,
#   'result': [{'from': '12.243.130.230',
#     'ttl': 249,
#     'size': 140,
#     'rtt': 9.871,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '12.243.130.230',
#     'ttl': 249,
#     'size': 140,
#     'rtt': 13.536,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '12.243.130.230',
#     'ttl': 249,
#     'size': 140,
#     'rtt': 13.915,
#     'icmpext': {'version': 0,
#      'rfc4884': 1,
#      'obj': [{'class': 0, 'type': 0}]}}]},
#  {'hop': 6,
#   'result': [{'from': '12.122.132.121', 'ttl': 250, 'size': 68, 'rtt': 11.163},
#    {'from': '12.122.132.121', 'ttl': 250, 'size': 68, 'rtt': 20.406},
#    {'from': '12.122.132.121', 'ttl': 250, 'size': 68, 'rtt': 11.431}]},
#  {'hop': 7,
#   'result': [{'from': '154.54.12.85', 'ttl': 249, 'size': 68, 'rtt': 9.773},
#    {'from': '154.54.12.85', 'ttl': 249, 'size': 68, 'rtt': 8.353},
#    {'from': '154.54.12.85', 'ttl': 249, 'size': 68, 'rtt': 10.193}]},
#  {'hop': 8,
#   'result': [{'from': '38.122.180.18',
#     'ttl': 248,
#     'size': 68,
#     'rtt': 8.811,
#     'itos': 72},
#    {'from': '38.122.180.18', 'ttl': 248, 'size': 68, 'rtt': 9.149, 'itos': 72},
#    {'from': '38.122.180.18',
#     'ttl': 248,
#     'size': 68,
#     'rtt': 8.88,
#     'itos': 72}]},
#  {'hop': 9,
#   'result': [{'from': '66.38.60.105',
#     'ttl': 237,
#     'size': 140,
#     'rtt': 40.93,
#     'itos': 72,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '66.38.60.105',
#     'ttl': 237,
#     'size': 140,
#     'rtt': 38.412,
#     'itos': 72,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '66.38.60.105',
#     'ttl': 237,
#     'size': 140,
#     'rtt': 38.572,
#     'itos': 72,
#     'icmpext': {'version': 0,
#      'rfc4884': 1,
#      'obj': [{'class': 0, 'type': 0}]}}]},
#  {'hop': 10,
#   'result': [{'from': '66.38.60.16',
#     'ttl': 238,
#     'size': 140,
#     'rtt': 39.578,
#     'ittl': 2,
#     'itos': 72,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '66.38.60.16',
#     'ttl': 238,
#     'size': 140,
#     'rtt': 38.819,
#     'ittl': 2,
#     'itos': 72,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '66.38.60.16',
#     'ttl': 238,
#     'size': 140,
#     'rtt': 39.486,
#     'ittl': 2,
#     'itos': 72,
#     'icmpext': {'version': 0,
#      'rfc4884': 1,
#      'obj': [{'class': 0, 'type': 0}]}}]},
#  {'hop': 11,
#   'result': [{'from': '66.38.58.5',
#     'ttl': 239,
#     'size': 140,
#     'rtt': 38.472,
#     'ittl': 3,
#     'itos': 72,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '66.38.58.5',
#     'ttl': 239,
#     'size': 140,
#     'rtt': 38.381,
#     'ittl': 3,
#     'itos': 72,
#     'icmpext': {'version': 0, 'rfc4884': 1, 'obj': [{'class': 0, 'type': 0}]}},
#    {'from': '66.38.58.5',
#     'ttl': 239,
#     'size': 140,
#     'rtt': 38.135,
#     'ittl': 3,
#     'itos': 72,
#     'icmpext': {'version': 0,
#      'rfc4884': 1,
#      'obj': [{'class': 0, 'type': 0}]}}]},
#  {'hop': 12,
#   'result': [{'from': '66.38.58.90',
#     'ttl': 240,
#     'size': 68,
#     'rtt': 37.839,
#     'itos': 64},
#    {'from': '66.38.58.90', 'ttl': 240, 'size': 68, 'rtt': 37.651, 'itos': 64},
#    {'from': '66.38.58.90',
#     'ttl': 240,
#     'size': 68,
#     'rtt': 37.558,
#     'itos': 64}]},
#  {'hop': 13,
#   'result': [{'from': '66.38.60.19',
#     'ttl': 243,
#     'size': 68,
#     'rtt': 37.079,
#     'itos': 64},
#    {'from': '66.38.60.19', 'ttl': 243, 'size': 68, 'rtt': 37.143, 'itos': 64},
#    {'from': '66.38.60.19',
#     'ttl': 243,
#     'size': 68,
#     'rtt': 36.774,
#     'itos': 64}]},
#  {'hop': 14,
#   'result': [{'from': '63.135.176.194',
#     'ttl': 242,
#     'size': 68,
#     'rtt': 37.303,
#     'itos': 64},
#    {'from': '63.135.176.194',
#     'ttl': 242,
#     'size': 68,
#     'rtt': 39.317,
#     'itos': 64},
#    {'from': '63.135.176.194',
#     'ttl': 242,
#     'size': 68,
#     'rtt': 36.944,
#     'itos': 64}]},
#  {'hop': 15,
#   'result': [{'from': '149.149.2.70',
#     'ttl': 50,
#     'size': 76,
#     'rtt': 38.479,
#     'itos': 64},
#    {'from': '149.149.2.70', 'ttl': 50, 'size': 76, 'rtt': 38.542, 'itos': 64},
#    {'from': '149.149.2.70',
#     'ttl': 50,
#     'size': 76,
#     'rtt': 38.027,
#     'itos': 64}]},
#  {'hop': 16,
#   'result': [{'from': '149.149.2.70', 'ttl': 49, 'size': 48, 'rtt': 38.912},
#    {'from': '149.149.2.70', 'ttl': 49, 'size': 48, 'rtt': 38.161},
#    {'from': '149.149.2.70', 'ttl': 49, 'size': 48, 'rtt': 37.828}]}]
